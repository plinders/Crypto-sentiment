# %%
import argparse

from google.cloud import language
from google.cloud.language import enums
from google.cloud.language import types

# %%
import tweepy
import pandas as pd
import numpy as np
from IPython.display import display
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
from credentials import *

# %%
def twitter_setup():
    auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
    auth.set_access_token(ACCESS_TOKEN, ACCESS_SECRET)
    
    api = tweepy.API(auth)
    return api

# %%
extractor = twitter_setup()

search_text = "$btc"

tweets = extractor.search(search_text, rpp=100)

print("Number of tweets extracted: {}.\n".format(len(tweets)))

print("5 recent tweets:\n")
for tweet in tweets[:2]:
    print(tweet.text)
    print()
# Out:
# Number of tweets extracted: 15.
#
# 5 recent tweets:
#
# RT @Cryptodumpster: Don't get caught up in the fake news!  This is NOT an official #OKcash account. 🚨🚨🚨Scam Alert! 🚨🚨🚨 DYOR $OK $BTC #bitco…
#
# A NEW WORLD... AGE OF AQUARIUS FOLKS! There's no stopping true change. Change happens through a certain faith, whic… https://t.co/aW0J8gozZS

# %%
for tweet in tweepy.Cursor(extractor.search, q = search_text, rpp=100).items(100000):
    print(tweet.text)
    print()
# Out:
# RT @OGBTC: I bought $BTC at $0.05.
# RT and I'll give some away to 100 ppl.
#
# RT @OGBTC: I bought $BTC at $0.05.
# RT and I'll give some away to 100 ppl.
#
# RT @ORACLEofETH: WOW #bitcoin16k
#
# If #Bitcoin hits 20K by this weekend...
# Ill send 1 $BTC to EVERYONE that RETWEETS and LIKES this
#
# Buy $10…
#
# RT @CryptoGat: #bcash $BCC also is supposed to open trading on @coinbase before Jan 1 +++ viaBTC is launching bcash trading pairs
#
# I am not…
#
# RT @CryptoGat: #bcash $BCC also is supposed to open trading on @coinbase before Jan 1 +++ viaBTC is launching bcash trading pairs
#
# I am not…
#
# $TRST CEO George is talking at the east-west conference in 2 days!
#
# $crypto $btc $eth $omg $knc
#
# https://t.co/kibXtNtrwb
#
# RT @OGBTC: I bought $BTC at $0.05.
# RT and I'll give some away to 100 ppl.
#
# RT @mBTCPizpie: This .gif is .fantastic.
# What is your profession?
#
# #bitcoin $btc https://t.co/xE5n7vzIrH
#
# RT @mango6710: I bought some bitcoin in 2011 for $2.90 each. I will pick 15 random people who retweet this and give 0.2 BTC to each of you.…
#
# RT @sentimentrader: Bitcoin has triggered 100% of the blow-off signals we look for. The next 1-3 months will be...interesting. $BTC $btcusd…
#
# @itzRene17 Sold my $BQX/$ETHOS at $.91 / 0.00016033 BTC it’s now at 0.00009353 so I have more $BTC value then anyone whole still holds bags.
#
# RT @CypherTrading: Is there another pump for $BCH incoming?
#
# If it breaks out of the channel, there is a good chance it will reach 2000$ ag…
#
# RT @RoyOlse93073002: $kmd will add #LightningNetwork and #smartcontracts as next step after BarterDEX and dICO: "That being said, one of th…
#
# RT @MEMESG0D: *buys 0.000001 bitcoin*
#
# *changes bio*
#
# Investor 💰 $BTC 💵 Living life in the sky ✈️ ☁️ Eat, Sleep, Bitcoin
#
# RT @BitcoinCashFans: CoinEx is a new exchange launching this month, trading only $BCH currency pairs!
#
# Starting with:
# $ZEC / BCH
# $ETH / BCH…
#
# We're seeing a wave of people who don't care about #bitcoin ( $BTC ), only want what it could represent: (i) potent… https://t.co/luugbiLBSo
#
# TRADING TIP: U can find best performing traders here: https://t.co/wWYYYAUGM4 &amp; COPY them with $BTC ! 💰💰
#
# $VIVO… https://t.co/6EObWtytmH
#
# @elonmusk Would it be in any way possible to buy a Tesla Roadster with the amazing #Stratis #crypto coin? #bitcoin $STRAT $BTC
#
# RT @kawaii_crypto: The mega #crypto sticker pack!! https://t.co/C8KTApT7U6 $btc $eth $bch $iota $$xrp $ltc $dash $xmr $neo $mona #kawaiicry…
#
# RT @parabolictrav: My general thoughts on what happens with futures? We open, lots of firms who want to hedge their $BTC to make CFOs happy…
#
# RT @BulwarkCoin: The first #Bulwark masternodes have appeared on the network! Would you like one too? Like, Follow, Retweet and we will cho…
#
# RT @OGBTC: Still giving away some $BTC to 100 ppl.
# I did get in at $0.05
# Here's the proof for the haters.
# You must RT, &amp; FOLLOW
# https://t.c…
#
# RT @CryptoNewswire: New ViaBTC Exchange to Use Bitcoin Cash as Base Trading Pair - https://t.co/nLxk0z4r6D $BCH $BTC #blockchain #trading #…
#
# RT @BitcoinCashFans: CoinEx is a new exchange launching this month, trading only $BCH currency pairs!
#
# Starting with:
# $ZEC / BCH
# $ETH / BCH…
#
# For round the clock updates of the #Bitcoin price please follow BTCpx #BTC #BTCUSD $BTC https://t.co/lPU82eyOCS
#
# RT @aajaji_m: I just published an article about #Ardor blockchain and how it's a game changer when it comes to #Scalability &amp; sustainable b…
#
# RT @mBTCPizpie: This .gif is .fantastic.
# What is your profession?
#
# #bitcoin $btc https://t.co/xE5n7vzIrH
#
# RT @vintagebazaarOB: #Bitcoin and #Altcoins Trading on #Binance.
# Very Impressed with the  Exchange.  Give them a try today!
# Fast Deposits,…
#
# RT @cryptodemedici: $LTC will gain a lot once people realize how slow transactions speeds are in $ETH and $BTC.
#
# RT @actualIizing: Bought 1,500 bitcoin in 2011 for $2.81 each. I will pick 20 random people who retweet this and give one to each of you. M…
#
# RT @parabolictrav: My general thoughts on what happens with futures? We open, lots of firms who want to hedge their $BTC to make CFOs happy…
#
# @Vertcoin what are we thinking the halving will do to the price? Know what it’ll go up but what is everyone’s predictions!? $VTC $ALT $BTC
#
# @WolfOfPoloniex @bitfinex No surprise. Had $BTC (and $USD) stolen by @bitfinex yesterday when they liquidated a… https://t.co/3XoSnnQaa5
#
# #MarketAlert (Last 24h):
# Top 100 price change: +2.8% (avg)
# 48 of the top 100 coins declining
# bitcoin: -4.4% $BTC… https://t.co/8B3KMLcEp3
#
# Worst returns (24h):
# 1. Decentraland -23.2% $MANA
# 2. NAVCoin -16.7% $NAV
# 3. stratisplatform -13.0% $STRAT… https://t.co/nEb682oEyM
#
# RT @Hstockpicks: @iamjosephyoung Big time!! Millionaires and billionaires will pile in!!! SUPPLY DEMAND WILL PUSH HIGHER!! Really like @cvp…
#
# How to buy #bitcoin with credit card ?
# you can use Cexio ( https://t.co/2RmWFe4Ki7 )
# thats the most trusted site… https://t.co/6Od1hXMcs8
#
# RT @parabolictrav: My general thoughts on what happens with futures? We open, lots of firms who want to hedge their $BTC to make CFOs happy…
#
# @yvnglioon $BTC
#
# RT @thecryptojew: Back in 2001 I purchased 1,000,000 $BTC for 0.00000001.
#
# I’m giving away 1,000 BTC to 5 lucky people. All you got to do…
#
# #MarketAlert (Last 24h):
# Top 100 price change: +2.8% (avg)
# 48 of the top 100 coins declining
# @bitcoin: -4.4% $BTC https://t.co/7FbxSRfSQl
#
# RT @OGBTC: I bought $BTC at $0.05.
# RT and I'll give some away to 100 ppl.
#
# RT @baconcraves: more exchanges adding $nxt!! what?! it's gonna moon so hard!
#
# $btc $strat $ardr $mona #emc2 $vtc $thc $eth $ltc #crypto
#
# RT @actualIizing: Bought 1,500 bitcoin in 2011 for $2.81 each. I will pick 20 random people who retweet this and give one to each of you. M…
#
# RT @cryptodemedici: $LTC will gain a lot once people realize how slow transactions speeds are in $ETH and $BTC.
#
# Bought back the 30% $BCH I sold back at the fork, at 1:1, I can now be at peace. Not looking forward to the coming… https://t.co/8GQ979lhO4
#
# RT @CryptoGat: #bcash $BCC also is supposed to open trading on @coinbase before Jan 1 +++ viaBTC is launching bcash trading pairs
#
# I am not…
#
# Greetings and Salutations, $13,000! https://t.co/v1EkFlvb35 #bitcoin #BitcoinPrice $btc
# $btcusd https://t.co/V8V0TrZP8K
#
# Yes, and soon they’ll be using $BTC which would have avoided this whole mess https://t.co/BHJILdd0h4
#
# RT @parabolictrav: My general thoughts on what happens with futures? We open, lots of firms who want to hedge their $BTC to make CFOs happy…
#
# RT @TeamGucciPlays: $XRP #Ripple in a breakout pattern 👏😍📈🔥 Look how far it fell over the last few months also wow the ROI potential on thi…
#
# RT @CryptoGat: #bcash $BCC also is supposed to open trading on @coinbase before Jan 1 +++ viaBTC is launching bcash trading pairs
#
# I am not…
#
# RT @JovanLloyd2017: The DEATH 💀 of $BTC Bitcoin Core is getting t closer and closer. $BCH BITCOIN CASH 💰 is taking OVER IN 2018!! https://t…
#
# RT @CryptoGat: #bcash $BCC also is supposed to open trading on @coinbase before Jan 1 +++ viaBTC is launching bcash trading pairs
#
# I am not…
#
# $16,000 and Up: Bitcoin Price Hits New All-Time High, is There a Limit? https://t.co/ArSBmYe2gt #bitcoin #ethereum… https://t.co/OoON5TCKmA
#
# Current $NEO price: $36.56
#
# Buy on Binance with 50% discount trading fee
#
# https://t.co/CIgsuCMGqM
#
# $DMD $ARK… https://t.co/HyRn355qAc
#
# RT @OGBTC: I bought $BTC at $0.05.
# RT and I'll give some away to 100 ppl.
#
# RT @Sophia_TX_: Exchange rates for the second round are:
# $ETH/BTC 0.026864919500000008
# $BTC/ $DTC 0.00003916320000000001
# #SophiaTX #TGE #I…
#
# Russia Weighing Ban On Cryptocurrency Mining https://t.co/7DOmXEPzHE #bitcoin #ethereum #blockchain #ico #btc #eth… https://t.co/WMe6DdtJjQ
#
# RT @tyfrankelmusic: Song about bitcoin $BTC coming soon via @ShutDownMusic. Thanks to @JFulfordtheIII for the idea!
#
# RT @TaIhaYilmaz: 1 $LTC #giveaway to one randomly chosen follower.
# Rules are
# 1. Follow
# 2. Retweet
# 3. Comment your wallet address
#
# Winne…
#
# RT @TheeFreshman: $BTC/USD Less is more, temporary lines drawn in the sand. Still printing lower highs, nice bband bulge might need to brea…
#
# RT @parabolictrav: My general thoughts on what happens with futures? We open, lots of firms who want to hedge their $BTC to make CFOs happy…
#
# RT @CryptosQueen: Don't ignore this. If you missed $BTC at 100s buy $LTC 100's you need to really go ALL IN. Litecoin is seriously the litt…
#
# RT @mBTCPizpie: This .gif is .fantastic.
# What is your profession?
#
# #bitcoin $btc https://t.co/xE5n7vzIrH
#
# 5 min #RSI Signals:
#
# $BTC - $WAVES: 28.33
# $BTC - $XLM: 28.66
# $BTC - $IOP: 29.81
# $BTC - $STEEM: 30.92
# $BTC - $XZC: 31.6
#
# $GUP $MUE $SBD
#
# 15 min #RSI Signals:
#
# $BTC - $LSK: 30.91
# $BTC - $SBD: 34.29
# $BTC - $IOP: 37.39
# $BTC - $WAVES: 38.98
#
# $STORJ $EMC2 $MER $SLS $GCR $RLC $OK
#
# RT @OphirGottlieb: Every time you see headline '1000 ppl own 40% of $BTC ' remember:
#
# * 1 person owns 60% of $FB voting power (Zuck)
# * 1 pe…
#
# RT @LegendsRoom: We welcome all the  #crypto cowboys in #vegas for #NFR2017  You can pay in $BTC and talk rodeo under our roof.  #bitcoin #…
#
# RT @Cryptodumpster: Don't get caught up in the fake news!  This is NOT an official #OKcash account. 🚨🚨🚨Scam Alert! 🚨🚨🚨 DYOR $OK $BTC #bitco…
#
# A NEW WORLD... AGE OF AQUARIUS FOLKS! There's no stopping true change. Change happens through a certain faith, whic… https://t.co/aW0J8gozZS
#
# $BTC/USD Less is more, temporary lines drawn in the sand. Still printing lower highs, nice bband bulge might need t… https://t.co/V9dsJu3ng3
#
# Yes. Very short term correlation is negative because they are investing substitutes. Longer term between $LTC and… https://t.co/yVg5ySjWnb
# @RampCapitalLLC $BTC surge, 24 hours later alt surge, crypto is crazy fun!
#
# RT @cgcardona: It's so outrageously frustrating when you mention a $BTC tx which is stuck in the mempool and someone replies "chill. Lightn…
#
# RT @TraceMayer: #Bitcoin is a sterile asset. $BTC measures how far along transfer of wealth process is. Once wealth is transferred to #Bitc…
#
# What I learned since $BTC beat all my $crypto alt trading up this week.
# 1) Sometimes take your 4% gain and run. No… https://t.co/2mzZ34SjRf
#
# RT @CryptoGat: #bcash $BCC also is supposed to open trading on @coinbase before Jan 1 +++ viaBTC is launching bcash trading pairs
#
# I am not…
#
# RT @OphirGottlieb: Every time you see headline '1000 ppl own 40% of $BTC ' remember:
#
# * 1 person owns 60% of $FB voting power (Zuck)
# * 1 pe…
#
# RT @parabolictrav: My general thoughts on what happens with futures? We open, lots of firms who want to hedge their $BTC to make CFOs happy…
#
# RT @ORACLEofETH: WOW #bitcoin16k
#
# If #Bitcoin hits 20K by this weekend...
# Ill send 1 $BTC to EVERYONE that RETWEETS and LIKES this
#
# Buy $10…
#
# @Timcast Tim start doing more $BTC and $crypto videos. Also get onboard the $Flixx train already. https://t.co/8aZpQMjpNW
#
# RT @CryptoBully: You really want to stick it to the banking sector?  Hit ‘em where it hurts?
#
# Then don’t use your $BTC profits to buy that…
#
# RT @OGBTC: Still giving away some $BTC to 100 ppl.
# I did get in at $0.05
# Here's the proof for the haters.
# You must RT, &amp; FOLLOW
# https://t.c…
#
# RT @LegendsRoom: We have the best #crypto strippers in the world...wait they are the only $BTC strippers in the world https://t.co/3NuQBzyx…
#
# RT @FreeASeed2016: The Aucklander doesn't actually deal directly in #bitcoin. His focus is on other, less well-known #virtual #currencies l…
#
# RT @parabolictrav: My general thoughts on what happens with futures? We open, lots of firms who want to hedge their $BTC to make CFOs happy…
#
# RT @SimonDixonTwitt: People ask me when is a good time to cash out #Bitcoin - my response is the same. I ask them when they will cash out t…
#
# Who wins in a fight, 1 #DRGN or 1000 #CrypoKitties ?
#
# @dragonchaingang has huge things in store
#
# $DRGN #DRGN #cryptokitties $ETH $BTC
#
# RT @OGBTC: Still giving away some $BTC to 100 ppl.
# I did get in at $0.05
# Here's the proof for the haters.
# You must RT, &amp; FOLLOW
# https://t.c…
#
# RT @parabolictrav: My general thoughts on what happens with futures? We open, lots of firms who want to hedge their $BTC to make CFOs happy…
#
# RT @vinarmani: So today we are seeing mom and pop money chasing yesterday's $BTC manipulation and the ensuing media hype. That's why today…
#
# With Steam no longer accepting Bitcoin payments, #Litecoin closes the gap with the help of @bitrefill. Problem solv… https://t.co/3yAmiyvXT4
#
# RT @OGBTC: I bought $BTC at $0.05.
# RT and I'll give some away to 100 ppl.
#
# RT @mango6710: I bought some bitcoin in 2011 for $2.90 each. I will pick 15 random people who retweet this and give 0.2 BTC to each of you.…
#
# RT @XVGWhale: $XVG has just hit a new all time high today, $0.0091! We are getting very close to breaking the $0.01 threshold for the first…
#
# RT @YpsiNine: Calling all #Bitcoin $BTC holders! Claim your #Bitcore $BTX for free and participate in the weekly airdrops. More info here:…
#
# Pepecash Price In USD, Bitcoin and XCP
#
# $USD
# Pepecash Price $0.09
# $BTC
# Pepecash Price 0.00000637
# $XCP
# Pepecash Price 0.0038191555
#
# RT @RampCapitalLLC: Congrats to everyone who sold the top in $BTC and rotated perfectly into Litecoin and Ethereum.
#
# RT @aajaji_m: I just published an article about #Ardor blockchain and how it's a game changer when it comes to #Scalability &amp; sustainable b…
#
# RT @TeamGucciPlays: $XRP #Ripple in a breakout pattern 👏😍📈🔥 Look how far it fell over the last few months also wow the ROI potential on thi…
#
# RT @cryptoBuzzB: While we watch $btc react as not exactly the fastest way to move $crypto around. $dnr with the 147tps. 💋
# #bitcoin problems…
#
# Current $ETH price: $455.62
#
# Buy on Binance with 50% discount trading fee
#
# https://t.co/CIgsuCMGqM
#
# $BTG $LSK… https://t.co/YnUg2jG3Fu
#
# $XRP #Ripple in a breakout pattern 👏😍📈🔥 Look how far it fell over the last few months also wow the ROI potential on… https://t.co/yZkuEgRb5d
#
# RT @YpsiNine: Calling all #Bitcoin $BTC holders! Claim your #Bitcore $BTX for free and participate in the weekly airdrops. More info here:…
#
# Like 4 years ago someone randomly sent me a #bitcoin.
# So.... what do I do with it!?
# $btc
#
# RT @btc: This has been a crazy week:
#
# $11,000 - $12,000: 6 days
# $12,000 - $13,000: 17 hours
# $13,000 - $14,000: 4 hours
# $14,000 - $15,000: 1…
#
# $XEM Thank's for 150% in 20 min.🤑🤑😍😍😂😂
# $ETH $BTC $ETC $BCH $BCC $XRP $NEO $DGB $LTC $XMR $NEM $DOGE $BAY $OK… https://t.co/w0zTsskkf4
#
# RT @BitcoinCashFans: CoinEx is a new exchange launching this month, trading only $BCH currency pairs!
#
# Starting with:
# $ZEC / BCH
# $ETH / BCH…
#
# RT @LegendsRoom: We have the best #crypto strippers in the world...wait they are the only $BTC strippers in the world https://t.co/3NuQBzyx…
#
# @EtikaWNetwork remember when I told you not to buy $btc last night because it was going to crash.
#
# RT @CryptoGat: #bcash $BCC also is supposed to open trading on @coinbase before Jan 1 +++ viaBTC is launching bcash trading pairs
#
# I am not…
#
# RT @OGBTC: I bought $BTC at $0.05.
# RT and I'll give some away to 100 ppl.
#
# RT @Wujiiih: Result of #LoMoStar airdrop. The app was working poorly due to rapid growth of user base. But I was able to get few coins ;)…
#
# @bkunzi01 @hernzzzzzz this... but let's use this bastard to generate more true $BTC
#
# $Crypto "zo en nu een bavaria" and now a beer, done for now. Enjoy the weekend en next week $20k $BTC who knows, st… https://t.co/IoAUAXL7nZ
#
# Remember when people traded in their gold coins for paper money? 🤔 Pepperidge Farms remembers. #cryptocurrency $BTC… https://t.co/WzuGKYUeIx
#
# RT @EtherHood: $crypto people:
#
# the $ETH #faucet is OPEN today for the next 4 hours; here are the rules:
#
# 1. follow me and retweet this
# 2.…
#
# We have the best #crypto strippers in the world...wait they are the only $BTC strippers in the world https://t.co/3NuQBzyx8V
#
# Lot of folks in China are tweeting about $XEM - it is about 70 YEN, and they are planning to hit over 100 YEN! The… https://t.co/4fN0d55w77
#
# Great insight into what may actually happen with the opening of CME $BTC futures on Dec 18. “Predicting the futures… https://t.co/CJH81WH9nh
#
# RT @digitalassetu: $BTC - $15,833.40
# $ETH - $456.65
# $BCH - $1,462.26
# $XRP - $0.25
# $BTG - $262.98
# $LTC - $128.43
# $DASH - $743.27
# $IOTA - $4.…
#
# RT @actualIizing: Bought 1,500 bitcoin in 2011 for $2.81 each. I will pick 20 random people who retweet this and give one to each of you. M…
#
# RT @vinarmani: So today we are seeing mom and pop money chasing yesterday's $BTC manipulation and the ensuing media hype. That's why today…
#
# My general thoughts on what happens with futures? We open, lots of firms who want to hedge their $BTC to make CFOs… https://t.co/xNXvbvXBIB
#
# RT @TheCryptoPug: This is great chance to learn human psychology of the masses &amp; of yourself. If you are selling your alts at huge loss to…
#
# $btc https://t.co/mRl5uHPAJw
#
# RT @MOONACO_CARD: Here's to the early stages of Monaco Card... The future of Crypto Payment Playforms. Imminent growth next week, have your…
#
# RT @actualIizing: Bought 1,500 bitcoin in 2011 for $2.81 each. I will pick 20 random people who retweet this and give one to each of you. M…
#
# #bcash $BCC also is supposed to open trading on @coinbase before Jan 1 +++ viaBTC is launching bcash trading pairs… https://t.co/eBQGaYSyE1
#
# RT @parabolictrav: Imagine the boardroom meetings of the last 6 months where big whale firms are preparing to short $BTC. "This is excellen…
#
# RT @actualIizing: Bought 1,500 bitcoin in 2011 for $2.81 each. I will pick 20 random people who retweet this and give one to each of you. M…
#
# Current $BTC price: $15777.90
#
# Buy on Binance with 50% discount trading fee
#
# https://t.co/FglwxOYGQ8
#
# $ENJ $NMR… https://t.co/2me3AdTjzw
#
# RT @8bitandstuff: My prediction $BTC #Bitcoin will hit $21,000 USD and then crash down to $13,000 USD, before the next leg up to $40,000 US…
#
# RT @EthereumAddict: $BTC looking for longs on breakout of triangle or the bottom line. https://t.co/IknXLulBry
#
# In a dramatic display of irony, $BTC evangelists, hoping to replace fiat, celebrate record amount of fiat they can… https://t.co/zZ4taP9962
#
# $BTC - $15,833.40
# $ETH - $456.65
# $BCH - $1,462.26
# $XRP - $0.25
# $BTG - $262.98
# $LTC - $128.43
# $DASH - $743.27
# $IOTA… https://t.co/wLwQ5Y7JG4
#
# RT @OGBTC: I bought $BTC at $0.05.
# RT and I'll give some away to 100 ppl.
#
# RT @cryptodemedici: $LTC will gain a lot once people realize how slow transactions speeds are in $ETH and $BTC.
#
# RT @OGBTC: I bought $BTC at $0.05.
# RT and I'll give some away to 100 ppl.
#
# RT @CryptoTrillions: One of my clients just sent me their progress on just Bitcoin, Litecoin, Ethereum, and BCash. He started my program in…
#
# BTC domain names available for sale.
#
# - BTCCommodities(.com)
#
# - BTCIndexFunds(.com)
#
# - BTCMutualFund(.com)
#
# - BTCMu… https://t.co/Bk47KOPUwL
#
# RT @chaozempire: 📛📛📛XMAS GIVEAWAY📛📛📛
# The Last Time I Gave Away 1 $BTC to @TheCryptoShriMp.
#
# 🚀🚀🚀This Time 3 winners of 50 $LUX🚀🚀🚀
#
# Rules:
# -…
#
# RT @parabolictrav: 50% retrace of previous daily candle happening in a vertical down fashion. This is what you want to see in order to go h…
#
# RT @OGBTC: I bought $BTC at $0.05.
# RT and I'll give some away to 100 ppl.
#
# RT @oohellno: Dont forget $mco is getting listen next week on korean and japanis exchanges.
# There wil be a big update on monday.
# Buy now ch…
#
# RT @CypherTrading: Is there another pump for $BCH incoming?
#
# If it breaks out of the channel, there is a good chance it will reach 2000$ ag…
# RT @OGBTC: Still giving away some $BTC to 100 ppl.
# I did get in at $0.05
# Here's the proof for the haters.
# You must RT, &amp; FOLLOW
# https://t.c…
#
# RT @XVGWhale: $XVG has just hit a new all time high today, $0.0091! We are getting very close to breaking the $0.01 threshold for the first…
#
# RT @OGBTC: I bought $BTC at $0.05.
# RT and I'll give some away to 100 ppl.
#
# RT @BitcoinCashFans: CoinEx is a new exchange launching this month, trading only $BCH currency pairs!
#
# Starting with:
# $ZEC / BCH
# $ETH / BCH…
#
# RT @CryptoJoe10k: #Litecoin $LTC #LTC #Bitcoin #Btc $Btc #Cryptocurreny #Crypto https://t.co/mIyQVdBkEn
#
# RT @coinics: WeChat + $XEM (#NEM) is a big news.  We will see how #XEM can overcome $BTC rally https://t.co/XPn7GdyMe1
#
# RT @coin_artist: Pretty amazing to revisit this #bitcoin artwork from 2013 by @dhtenshi. $btc https://t.co/dyxt5cY3jU
#
# RT @Blockchainlife: If #Bitcoin keeps going up at these rates we are going to see some serious issues because there is only room for 1 Lamb…
#
# RT @crypto_rand: $BTC to 500K $ before the end of the year or I will eat a Kobe steak like this one on a public restaurant. Word $Crypto ht…
#
# RT @OGBTC: Still giving away some $BTC to 100 ppl.
# I did get in at $0.05
# Here's the proof for the haters.
# You must RT, &amp; FOLLOW
# https://t.c…
#
# This guy gets it. $btc #bitcoin https://t.co/dasPbK6JR8
#
# RT @TheElementGrp: Just two days to go till the launch of #Bitcoin futures. Futures bring legitimacy and validation to $BTC as an asset cla…
#
# $BTC volume is looking low enough now for a big move. Easy to move the market when it gets down this low. https://t.co/emjTH76mkA
#
# get 50 spins to win some btc, you don't have to deposit anything.
# https://t.co/hlUzjPsgoG
#
# $BTC $BCC… https://t.co/41lFUQyucN
#
# @WolfOfPoloniex Damn Wolf sell alot of bitcoin? Too many people want correction, price will go up $btc
#
# RT @Crypto_McDuck: Price predictions for end of 2018:
#
# $BTC = $25,000
# $ETH = $2,000
# $LTC = $350
# $XRP = $1.50
# $DASH = $1500
# $BCH = $2000
# $XL…
#
# Join in on @cheddar's, The Crypto Craze Show! Talk on crypto from a major business news network. #blockchain… https://t.co/roc9QD5wWX
#
# RT @PasteMagazine: 9 reasons why I think the banks may be manipulating $BTC https://t.co/Imo35mNTfy https://t.co/uCRwpTLNqV
#
# RT @actualIizing: Bought 1,500 bitcoin in 2011 for $2.81 each. I will pick 20 random people who retweet this and give one to each of you. M…
#
# RT @Fullbeerbottle: It's been a little while since I last said this, so:
#
# Please don't ask anyone how much #Bitcoin they have.
#
# It's the s…
#
# RT @actualIizing: Bought 1,500 bitcoin in 2011 for $2.81 each. I will pick 20 random people who retweet this and give one to each of you. M…
#
# RT @ZoomStocks: Daily Roundup: $Yields 10Y: S.Korea +1.5 bps, Canada +1.0 bps. $Gold ↑+0.14% $1,249.50. $BTC ↓-9.2% $15,602.0x. $Brent #Cru…
#
# @loadsofloveamy @CaitlinSLALW Read some stuff $btc
#
# RT @rrrrewssdd: $ltc should be at $1,000 $bch $btc $vtc $eth
#
# 5 min #RSI Signals:
#
# $BTC - $KMD: 28.3
# $BTC - $IOP: 30.66
# $BTC - $LSK: 30.78
# $BTC - $XZC: 31.56
# $BTC - $XLM: 31.9
#
# $MEME $SBD $NMR $VTR
#
# La razón por la que el $BTC no se comporta como nada que hayamos visto antes es porque es algo que no hemos visto antes.
#
# RT @mango6710: continue to retweet. i will give away 0.2 BTC to 15 lucky people. #bitcoin #BTC $BTC https://t.co/gnSd1dXLc3
#
# RT @actualIizing: Bought 1,500 bitcoin in 2011 for $2.81 each. I will pick 20 random people who retweet this and give one to each of you. M…
#
# Hahahaha $XEM
#
# UPDATE: 400% profit IN LESS THAN 8 HOURS!!!
#
# (0.000012 -&gt; 0.000048)
#
# You just gotta BELIEVE!
#
# Follow… https://t.co/XXkcsYaABa
#
# RT @OGBTC: I bought $BTC at $0.05.
# RT and I'll give some away to 100 ppl.
#
# RT @btc: Bitcoin Giveaway #2: As promised, we will be giving away 1 BTC when we hit 100k followers! Please RT and Follow for a chance to wi…
#
# RT @thecryptojew: Back in 2001 I purchased 1,000,000 $BTC for 0.00000001.
#
# I’m giving away 1,000 BTC to 5 lucky people. All you got to do…
#
# RT @decredproject: You can now compare #Decred to other $crypto projects on specifications, features, and governance.
#
# This iteration inclu…
#
# RT @BitcoinCashFans: CoinEx is a new exchange launching this month, trading only $BCH currency pairs!
#
# Starting with:
# $ZEC / BCH
# $ETH / BCH…
#
# RT @BitcoinCashFans: CoinEx is a new exchange launching this month, trading only $BCH currency pairs!
#
# Starting with:
# $ZEC / BCH
# $ETH / BCH…
#
# RT @OGBTC: I bought $BTC at $0.05.
# RT and I'll give some away to 100 ppl.
#
# RT @cryptodemedici: I want to be able to transfer $BTC to another address but via an anonymous crypto that makes my funds essentially disap…
#
# RT @cryptodemedici: $LTC will gain a lot once people realize how slow transactions speeds are in $ETH and $BTC.
#
# RT @cryptodemedici: $LTC will gain a lot once people realize how slow transactions speeds are in $ETH and $BTC.
#
# RT @dke82: I just published “Two issues to consider as bitcoin price goes parabolic“ on Medium. #bitcoin #Cryptocurreny $BTC https://t.co/r…
#
# Wall Street and Chicago Big Names are joining the Bitcoin Wagon - https://t.co/45pccr3IA7 $BTC #investing #trading #crypto
#
# RT @cryptodemedici: $LTC will gain a lot once people realize how slow transactions speeds are in $ETH and $BTC.
#
# We welcome all the  #crypto cowboys in #vegas for #NFR2017  You can pay in $BTC and talk rodeo under our roof.… https://t.co/7Gw4v8dUSC
#
# RT @CypherTrading: Is there another pump for $BCH incoming?
#
# If it breaks out of the channel, there is a good chance it will reach 2000$ ag…
#
# RT @CryptoBully: You really want to stick it to the banking sector?  Hit ‘em where it hurts?
#
# Then don’t use your $BTC profits to buy that…
#
# Man I'm so pumped for lightning! $BTC #bitcoin
#
# Got $BTC $LTC $ETH $ETC $ZEC or $DASH
# Time to get a hardware wallet and protect your valuable coins!
#
# 🔒 TREZOR via… https://t.co/gPyhoy4FPv
#
# RT @iiblockchain: GIVEAWAY ALERT!
#
# $100 of #STRATIS
#
# We are sending $100 worth of $STRAT to a lucky follower who RT's this message and giv…
#
# RT @optiongulf: البتكوين
#  $BTC #BITCOIN https://t.co/gDPQ3OzUPC
#
# @hernzzzzzz i take it to generate more true $BTC with this news - call me a bastard https://t.co/540dtfdFsg
#
# @ChrisPacia Just booked a trip on Expedia with $BTC.
#
# RT @cryptodemedici: $LTC will gain a lot once people realize how slow transactions speeds are in $ETH and $BTC.
#
# Can $NXT break the $1 barrier? 🚀
#
# #RETWEET
#
# $IGNIS $ARDR $BTC $ETH $LTC
#
# RT @cryptodemedici: $LTC will gain a lot once people realize how slow transactions speeds are in $ETH and $BTC.
#
# RT @YpsiNine: Calling all #Bitcoin $BTC holders! Claim your #Bitcore $BTX for free and participate in the weekly airdrops. More info here:…
#
# RT @coin_artist: Pretty amazing to revisit this #bitcoin artwork from 2013 by @dhtenshi. $btc https://t.co/dyxt5cY3jU
#
# RT @spwhaleclub: CHRISTMAS GIVEAWAY!💰🎅🎄
#
# ⚡️RT, LIKE &amp; FOLLOW TO ENTER!⚡️
#
# --
# 1 x Sealed Ledger Nano S
# 1 x Sealed Apple Airpods
# 1 $BTC
# 25K…
#
# RT @drewpeters: HODLers we get it.. you hoard and you hold, very clever. Please stop. It is such a new money attitude. No need to be cocky…
#
# RT @drewpeters: HODLers we get it.. you hoard and you hold, very clever. Please stop. It is such a new money attitude. No need to be cocky…
#
# RT @actualIizing: Bought 1,500 bitcoin in 2011 for $2.81 each. I will pick 20 random people who retweet this and give one to each of you. M…
#
# @ReformedBroker Friends don’t let friends drink and trade $BTC.
#
# RT @OGBTC: I bought $BTC at $0.05.
# RT and I'll give some away to 100 ppl.
#
# RT @CryptoNewswire: US adds 228K jobs in November [Video] - https://t.co/4wAb9nGF0p $BTC #bitcoin #cryptocurrency #news
#
# US adds 228K jobs in November [Video] - https://t.co/4wAb9nGF0p $BTC #bitcoin #cryptocurrency #news
#
# Drop any alt coin below and ill chart it and give my thoughts, $BTC
#
# RT @OGBTC: I bought $BTC at $0.05.
# RT and I'll give some away to 100 ppl.
#
# RT @cryptodemedici: $LTC will gain a lot once people realize how slow transactions speeds are in $ETH and $BTC.
#
# RT @LatiumCoin: The Next Buyer #bonus at https://t.co/3Q9NESwW9V is a great way to participate! Go check it out now! $ETH $BTC https://t.co…
#
# RT @TaIhaYilmaz: 1 $LTC #giveaway to one randomly chosen follower.
# Rules are
# 1. Follow
# 2. Retweet
# 3. Comment your wallet address
#
# Winne…
#
# RT @coinmarketwatch: #CryptoAllTimeHighs  $SBD $DEM $VTR $NXT $BTC  #cryptocurrency #bitcoin - https://t.co/NbxYjeBRH5 https://t.co/tduGV7g…
#
# RT @actualIizing: Bought 1,500 bitcoin in 2011 for $2.81 each. I will pick 20 random people who retweet this and give one to each of you. M…
#
# RT @cryptodemedici: $LTC will gain a lot once people realize how slow transactions speeds are in $ETH and $BTC.
# I thought it was snowing yesterday, but it turned out to be newbies that bought to the moon. 🤣
#
# #bitcoin $btc https://t.co/ZmMaDZPwZr
#
# 20171208 $BURST holding strong during this $BTC rally - Strong project I want you baby https://t.co/ua9I5tRIzg
#
# RT @cryptodemedici: $LTC will gain a lot once people realize how slow transactions speeds are in $ETH and $BTC.
#
# One day $BTC price become insane🤑 https://t.co/oHj9r1UzoN
#
# $BTC DASH and Litecoin Analysis December 11, 2017: DASH/USD DASH continues to be very risky… https://t.co/AjaKSpLJ9m
#
# RT @rrrrewssdd: $ltc should be at $1,000 $bch $btc $vtc $eth
#
# $ltc should be at $1,000 $bch $btc $vtc $eth
#
# Se pasó una enmienda en E.U. que afecta a $BTC, más que nada a las empresas de intercambio,  aquí la publicación de… https://t.co/L0J7OHerme
#
# RT @w4yneKER: Circle's CENTRE Spin-Off Raises $20 Million in SAFT Sale https://t.co/eV4vPHIiNs https://t.co/yu1yfEaMBo : #coindesk #crypto…
#
# Circle's CENTRE Spin-Off Raises $20 Million in SAFT Sale https://t.co/eV4vPHIiNs https://t.co/yu1yfEaMBo :… https://t.co/lt0TSMA2y5
#
# HODLers we get it.. you hoard and you hold, very clever. Please stop. It is such a new money attitude. No need to b… https://t.co/0DIYwK7W7t
#
# #Bitcoin $BTC #crypto https://t.co/upS8geupyN
#
# PRO TIP: Want to make some extra cash? Use $BTC to copy these awesome traders: https://t.co/RZGtPURQnY 💰💰
#
# $ONION… https://t.co/id1jmQahMX
#
# RT @SubstratumNet: Getting ready for the #Developer #AMA #3 in the @SubstratumNet offices! #substratum #sub $sub #cryptocurrency #blockchai…
#
# RT @btc: Bitcoin Giveaway #2: As promised, we will be giving away 1 BTC when we hit 100k followers! Please RT and Follow for a chance to wi…
#
# RT @actualIizing: Bought 1,500 bitcoin in 2011 for $2.81 each. I will pick 20 random people who retweet this and give one to each of you. M…
#
# Volgens mij hebben ze bij de @NOS redactie last van een kapot brein... Willen jullie alsjeblieft stoppen met schrij… https://t.co/f62cH7dcdE
#
# RT @ElixiumCrypto: A new #Crypto #meme that I just created! 🚀🚀🚀
#
# https://t.co/bB5yac5FdG
#
# $XBT $BTC $BTCUSD #XBT #BTC #BTCUSD #Bitcoin #Cr…
#
# Volumen de trade de $BTC. Excelente https://t.co/e2tYeDGOFY
#
# RT @ORACLEofETH: WOW #bitcoin16k
#
# If #Bitcoin hits 20K by this weekend...
# Ill send 1 $BTC to EVERYONE that RETWEETS and LIKES this
#
# Buy $10…
#
# RT @SubstratumNet: Interested in buying $SUB but don’t know how? Here is a step by step guide on how to buy #Substratum https://t.co/Sc5cwH…
#
# Die Gewinner des Finanzjahres 2017: #Bitcoin, chinesische Internetaktien und die #Lufthansa heben ab $BTC | via… https://t.co/O8VF94v6hP
#
# Major #Gold #Dealer #APMEX Begins Accepting #Bitcoin
# https://t.co/H109TPvRSu $BTC #Gold #Stocks #Investment… https://t.co/qM6oMcTJcl
#
# $HTML5 $HTML $BTC $QTUM $NEO #HTMLCOIN #HTML5 #BITCOIN #BTC #cryptocurrency #Altcoin #Fintech #Blockchain… https://t.co/LHKbImHN3h
#
# RT @BulwarkCoin: The first #Bulwark masternodes have appeared on the network! Would you like one too? Like, Follow, Retweet and we will cho…
#
# RT @btc: This has been a crazy week:
#
# $11,000 - $12,000: 6 days
# $12,000 - $13,000: 17 hours
# $13,000 - $14,000: 4 hours
# $14,000 - $15,000: 1…
#
# RT @cryptodemedici: $LTC will gain a lot once people realize how slow transactions speeds are in $ETH and $BTC.
#
# RT @SubstratumNet: The 10 Potential Winners for Day 2 of #Christmas w/ #Substratum have been chosen &amp; contacted for verification! 24 hrs to…
#
# RT @SubstratumNet: The 10 Potential Winners for Day 2 of #Christmas w/ #Substratum have been chosen &amp; contacted for verification! 24 hrs to…
#
# RT @cryptopedians: HOLYY SHIT!!! i am giving out 1.2 $btc to 1 winner!!!
#
# The winner will get 0.4 $btc X 3
#
# join if you haven't!!! winner…
#
# $BTC THE LAST TIME THE BANKERS GOT KICKED OUT WAS B.C and the cross is a t ...now it's BTC.
#
# This site allows you to COPY the best performing traders (with $BTC ). Check it out: https://t.co/DN5WMV6fvB 🚀🚀… https://t.co/lDOwesCHkG
#
# RT @mango6710: continue to retweet. i will give away 0.2 BTC to 15 lucky people. #bitcoin #BTC $BTC https://t.co/gnSd1dXLc3
#
# RT @LatiumCoin: The Next Buyer #bonus at https://t.co/3Q9NESwW9V is a great way to participate! Go check it out now! $ETH $BTC https://t.co…
#
# RT @totravelishuman: Most awaited product of the year was just released!!! Congratulations #STRATIS team! Bitcoin transactions can now be a…
#
# RT @OphirGottlieb: Every time you see headline '1000 ppl own 40% of $BTC ' remember:
#
# * 1 person owns 60% of $FB voting power (Zuck)
# * 1 pe…
#
# RT @dimsum_lose_sum: Can $nxt surpass 0.0001 $BTC? With $EMC2 behaving so crazily over nothing, it's possible we see a $2 per $NXT value be…
#
# RT @cryptopedians: 1.2 $btc Draw results ..... WOW!!!!!!! Please DM me your $btc address..... https://t.co/xR0TjB6rrI
#
# @Vertcoin what are we thinking the halving will do to the price? Know what it’ll go up but what is everyone’s predictions!? $VTC $ALT $BTC
#
# RT @actualIizing: Bought 1,500 bitcoin in 2011 for $2.81 each. I will pick 20 random people who retweet this and give one to each of you. M…
#
# RT @cryptopedians: Remember guys! its a $btc lucky draw!! anyone of you can win...... https://t.co/fPNUckSz97
#
# RT @SubstratumNet: @SubstratumNet CEO @overridepro quoted in @FastCompany article on #Bitcoin $btc https://t.co/hv8lbWIWqt #sub $sub #subst…
#
# RT @CryptosQueen: Don't ignore this. If you missed $BTC at 100s buy $LTC 100's you need to really go ALL IN. Litecoin is seriously the litt…
#
# RT @OGBTC: Still giving away some $BTC to 100 ppl.
# I did get in at $0.05
# Here's the proof for the haters.
# You must RT, &amp; FOLLOW
# https://t.c…
#
# RT @cryptopedians: For those who havn't won, be patient!!! there will be alot more $btc giveaways!!!!
#
# I am so eager to give $btc after it…
#
# RT @cryptodemedici: $LTC will gain a lot once people realize how slow transactions speeds are in $ETH and $BTC.
#
# RT @OGBTC: I bought $BTC at $0.05.
# RT and I'll give some away to 100 ppl.
#
# RT @actualIizing: Bought 1,500 bitcoin in 2011 for $2.81 each. I will pick 20 random people who retweet this and give one to each of you. M…
#
# $BTC related stocks. Gravestone Doji on $HIVE today. Look for pullback $RIOT looking to break higher out of triangle.
#
# RT @cryptopedians: Who wants another 1 $btc giveaway? join https://t.co/22KdrgOihF !!!
#
# $ltc $btc $eth $iop $trig $iota $aeon $strat $neo…
#
# RT @iiblockchain: GIVEAWAY ALERT!
#
# $100 of #STRATIS
#
# We are sending $100 worth of $STRAT to a lucky follower who RT's this message and giv…
#
# RT @OGBTC: Still giving away some $BTC to 100 ppl.
# I did get in at $0.05
# Here's the proof for the haters.
# You must RT, &amp; FOLLOW
# https://t.c…
#
# RT @MEMESG0D: *buys 0.000001 bitcoin*
#
# *changes bio*
#
# Investor 💰 $BTC 💵 Living life in the sky ✈️ ☁️ Eat, Sleep, Bitcoin
#
# $BTC VEDIC CHART! Jyotish. Currently in Mercury Dasha conjoined Jupiter in Capricorn. Mercury --Mer-chant. Mercury… https://t.co/wBgAnVA3Pn
#
# RT @cryptodemedici: $LTC will gain a lot once people realize how slow transactions speeds are in $ETH and $BTC.
#
# RT @cryptodemedici: $LTC will gain a lot once people realize how slow transactions speeds are in $ETH and $BTC.
#
# 5 min #RSI Signals:
#
# $BTC - $STEEM: 29.96
# $BTC - $XZC: 31.57
# $BTC - $EDG: 31.87
# $BTC - $NXT: 32.12
# $BTC - $XLM: 32.32
#
# $WAVES $THC $GCR
#
# RT @actualIizing: Bought 1,500 bitcoin in 2011 for $2.81 each. I will pick 20 random people who retweet this and give one to each of you. M…
#
# RT @OGBTC: I bought $BTC at $0.05.
# RT and I'll give some away to 100 ppl.
#
# RT @btc: Bitcoin Giveaway #2: As promised, we will be giving away 1 BTC when we hit 100k followers! Please RT and Follow for a chance to wi…
#
# RT @actualIizing: Bought 1,500 bitcoin in 2011 for $2.81 each. I will pick 20 random people who retweet this and give one to each of you. M…
#
# RT @OGBTC: Still giving away some $BTC to 100 ppl.
# I did get in at $0.05
# Here's the proof for the haters.
# You must RT, &amp; FOLLOW
# https://t.c…
#
# RT @CryptosQueen: Don't ignore this. If you missed $BTC at 100s buy $LTC 100's you need to really go ALL IN. Litecoin is seriously the litt…
#
# RT @OGBTC: I bought $BTC at $0.05.
# RT and I'll give some away to 100 ppl.
#
# @RogerMarisfan @jimcramer I'm a published novelist and an investor in $btc. Will be happy to discuss either/or with you.
#
# RT @TickerCandy: Applies to bitcoin too . $BTC #BTC https://t.co/j2gK44Sgqi
#
# RT @LucydLtd: Hey Lucyd comunity! Check out our roadshow schedule to see where you can meet us in person. More may be added soon so stay po…
#
# RT @CryptosQueen: Don't ignore this. If you missed $BTC at 100s buy $LTC 100's you need to really go ALL IN. Litecoin is seriously the litt…
#
# RT @actualIizing: Bought 1,500 bitcoin in 2011 for $2.81 each. I will pick 20 random people who retweet this and give one to each of you. M…
#
# I just published an article about #Ardor blockchain and how it's a game changer when it comes to #Scalability &amp; sus… https://t.co/ZEAZOxfXdH
#
# RT @Khil0ne: Exciting times ahead for @stratisplatform ! Hope you guys will be there to witness them. Have a good weekend! #stratis #bitcoi…
#
# RT @actualIizing: Bought 1,500 bitcoin in 2011 for $2.81 each. I will pick 20 random people who retweet this and give one to each of you. M…
#
# RT @OGBTC: I bought $BTC at $0.05.
# RT and I'll give some away to 100 ppl.
#
# RT @actualIizing: Bought 1,500 bitcoin in 2011 for $2.81 each. I will pick 20 random people who retweet this and give one to each of you. M…
#
# RT @iiblockchain: GIVEAWAY ALERT!
#
# $100 of #STRATIS
#
# We are sending $100 worth of $STRAT to a lucky follower who RT's this message and giv…
# RT @RNR_0: Haters will say it's photoshopped
# $BTC #bitcoin https://t.co/f73wlEosUM
#
# @cryptodemedici In theory, should it’s value not be 1/4 that of $BTC?
#
# XEM/BTC 1 Month High - New Economy Movement (XEM) price reaches 1 Month High on Poloniex - $XEM $BTC #finance #news #investing
#
# $CBOE $BTC $XBT #Bitcoin #Futures start trading on Dec 10, '17 @ 15:00 Central Time $XBT_F https://t.co/jl0WZ5FWv3
#
# RT @OGBTC: I bought $BTC at $0.05.
# RT and I'll give some away to 100 ppl.
#
# RT @cryptodemedici: $LTC will gain a lot once people realize how slow transactions speeds are in $ETH and $BTC.
#
# Current $OMG price: $8.60
#
# Buy on Binance with 50% discount trading fee
#
# https://t.co/R03EZXCfJV
#
# $VERI $FAIR… https://t.co/oQZJZnwm4P
#
# RT @OGBTC: I bought $BTC at $0.05.
# RT and I'll give some away to 100 ppl.
#
# I have a feeling when Korea and Asia wake up in a few hours they’re gonna crash the $BTC party
#
# RT @mango6710: I bought some bitcoin in 2011 for $2.90 each. I will pick 15 random people who retweet this and give 0.2 BTC to each of you.…
#
# RT @actualIizing: Bought 1,500 bitcoin in 2011 for $2.81 each. I will pick 20 random people who retweet this and give one to each of you. M…
#
# RT @BTCPriceBot: #BTC 24hr Summary:
# Last: $15730.64
# High: $17777.69
# Low: $13788.99
# Change: -2.36% | $-380.84
# Volume: $569,685,866.9
# $BTC #B…
#
# @lordmelchet47 Sell your $NVDA shares mate, because when $BTC crashes it's going to bring NVDA down and with it the markety!! #SPX $SPY
#
# RT @actualIizing: Bought 1,500 bitcoin in 2011 for $2.81 each. I will pick 20 random people who retweet this and give one to each of you. M…
#
# RT @vulken17: $CCTL
# BITCOIN POWER HOUR
# CONTRACTS SIGNED NEWS OF THE DEAL IMMINENT PER CEO TWEET
# @SHARETHIS @STOCKTWITS @TWITTER @CNBC @ALER…
#
# RT @vulken17: $CCTL
# BITCOIN POWER HOUR
# CONTRACTS SIGNED NEWS OF THE DEAL IMMINENT PER CEO TWEET
# @SHARETHIS @STOCKTWITS @TWITTER @CNBC @ALER…
#
# RT @mango6710: I bought some bitcoin in 2011 for $2.90 each. I will pick 15 random people who retweet this and give 0.2 BTC to each of you.…
#
# RT @mango6710: I bought some bitcoin in 2011 for $2.90 each. I will pick 15 random people who retweet this and give 0.2 BTC to each of you.…
#
# RT @kasoutsuutarou: $BTC の暴落に影響されるアルト、bittrexにあるほとんどの銘柄は死んだままかもしれない。
# しかしあまり影響を受けないアルトがあったとして、それはフィアットで買えるアルトだと思ってる。
# つまりフィアットの取引所に上場予定の $MCO…
#
# RT @MazumaDough: @WolfOfPoloniex @bitfinex It's not FUD, @krakenfx is under attack too... but they are attacked by their own tech team unfo…
#
# @WolfOfPoloniex @bitfinex It's not FUD, @krakenfx is under attack too... but they are attacked by their own tech te… https://t.co/mS5ABuBSV5
#
# RT @MEMESG0D: *buys 0.000001 bitcoin*
#
# *changes bio*
#
# Investor 💰 $BTC 💵 Living life in the sky ✈️ ☁️ Eat, Sleep, Bitcoin
#
# RT @EdBorgato: $BTC futures are to investing as Skittles are to food.
#
# ADA/BTC #Cardano You can clearly see the trend reversal.  Look at the #MACD and #RSI indicators. Look at the 4H can… https://t.co/y5LSOPY5Ez
#
# accidentally found myself on yahoo and saw this gem of an article.. also love how everyone in the comments is calli… https://t.co/C8hYXIhdGL
#
# 20171208 $ARDR ok ok $BTC is the cause for this bearish move - project has great great future https://t.co/qyanrFz7F2
#
# RT @cash_cashington: everyone obsessed w/ $BTC price, meanwhile... https://t.co/WyIgy90xDw
#
# @FelipeHuicochea Me parece acertada la analogía.
#
# Pero mehh, los analistas/traders/inversionistas con años de "expe… https://t.co/t2VTYJyqWP
#
# RT @TaIhaYilmaz: 1 $LTC #giveaway to one randomly chosen follower.
# Rules are
# 1. Follow
# 2. Retweet
# 3. Comment your wallet address
#
# Winne…
#
# $LTC will gain a lot once people realize how slow transactions speeds are in $ETH and $BTC.
#
# RT @contestpal: My $btc - $nxt - $emc2 - $ltc - $gcr friends... buy and hold $XEM for it has joined hands with Wechat - one of the largest…
#
# Applies to bitcoin too . $BTC #BTC https://t.co/j2gK44Sgqi
#
# $Nxt did it hope your enjoying profit boys &lt;3 $nxt $btc $ardr https://t.co/62tUtkQjlE
#
# @ErikSTownsend @MarinKatusa Great post game with @jessefelder and especially Robin Geffen. Best cycle analysis I've… https://t.co/JUYn8RKKhd
#
# RT @PeterLBrandt: Has there ever been a move like $BTC ? OH YEA!!! In early 1920s German Mark went from 4.2 DM per $1 USD to 4.5 billion DM…
#
# RT @BarryDutton: Well, #Bitcoin has grown 21X in 11 months.  What has YOUR BANK and debased fiat/government backed currency done for YOU an…
#
# RT @crypto_rand: $BCH // $BCC huge dick of volume and tiny breakout attempt. Looks aiming for a move in anticipation of a possible $BTC dro…
#
# What is $QTUM? An awesome coin which combines the best characteristics of $BTC and $ETH! https://t.co/3h9eqws0RF
#
# RT @ElixiumCrypto: A new #Crypto #meme that I just created! 🚀🚀🚀
#
# https://t.co/bB5yac5FdG
#
# $XBT $BTC $BTCUSD #XBT #BTC #BTCUSD #Bitcoin #Cr…
#
# RT @ElixiumCrypto: A new #Crypto #meme that I just created! 🚀🚀🚀
#
# https://t.co/bB5yac5FdG
#
# $XBT $BTC $BTCUSD #XBT #BTC #BTCUSD #Bitcoin #Cr…
#
# @douglaskphoto @crypt0snews Didn’t know $BTC was physical, do elaborate.
#
# RT @coin_artist: Pretty amazing to revisit this #bitcoin artwork from 2013 by @dhtenshi. $btc https://t.co/dyxt5cY3jU
#
# RT @coin_artist: Pretty amazing to revisit this #bitcoin artwork from 2013 by @dhtenshi. $btc https://t.co/dyxt5cY3jU
#
# RT @OGBTC: Still giving away some $BTC to 100 ppl.
# I did get in at $0.05
# Here's the proof for the haters.
# You must RT, &amp; FOLLOW
# https://t.c…
#
# You have to copy him.
#
# https://t.co/CQodgEYsDq
#
# $XZC $DCT $ETH $GNT $LTC $XLM $LMC $BTC $QTUM $MAID $FUN $CANN $BCH… https://t.co/76yZYeX24H
#
# Use $BTC to copy the best performing FOREX traders. Check it out: https://t.co/gioZXL3Tiv 💰💰
#
# $FIMK $BTC $ETP $UNB… https://t.co/9hpyVuhU0M
#
# RT @dailydosecrypto: Watch out for the next FREE Crypto Giveaway! 🤑🤑
#   #Bitcoin $BTC $BTCZ $LTC $BTCUSD
# Planning on 1 #LTC to two lucky win…
#
# RT @NetworksManager: How to Buy GlobalBoost® $BSTY With $BTC on Cryptopia via Coinbase.
# Ride Bitcoin wave with GlobalBoost®, a unique #Bloc…
#
# Most awaited product of the year was just released!!! Congratulations #STRATIS team! Bitcoin transactions can now b… https://t.co/wEDCcrs5D5
#
# RT @MEMESG0D: *buys 0.000001 bitcoin*
#
# *changes bio*
#
# Investor 💰 $BTC 💵 Living life in the sky ✈️ ☁️ Eat, Sleep, Bitcoin
#
# Bears are rallying the troops, positioning... positioning...
#
# #bitcoin $btc https://t.co/Hh03GwrzDt
#
# @kucoincom $XRB   If $BTC is gold then $XRB and $IOTA is cash
#
# RT @CryptosQueen: Don't ignore this. If you missed $BTC at 100s buy $LTC 100's you need to really go ALL IN. Litecoin is seriously the litt…
#
# @FiscalSuspicion @XVGWhale Huge $XVG fan.
#
# But it’s $0.01 because $BTC value is rising.  Not $XVG’s value......Vo… https://t.co/5hXEVnS9nG
#
# @jimcramer if big $BTC mines can sell forward, shouldn't it push price down to ~ marginal cost? who knows, its all speculation.
#
# what if instead about tweeting to BAN Bitcoin $BTC
#
# @POTUS tweets Takes Credit, and cheers for price climb
#
# $15,00… https://t.co/vDeasW6BRN
#
# RT @CryptoBully: You really want to stick it to the banking sector?  Hit ‘em where it hurts?
#
# Then don’t use your $BTC profits to buy that…
#
# RT @actualIizing: Bought 1,500 bitcoin in 2011 for $2.81 each. I will pick 20 random people who retweet this and give one to each of you. M…
#
# RT @RoyOlse93073002: $kmd will add #LightningNetwork and #smartcontracts as next step after BarterDEX and dICO: "That being said, one of th…
#
# Price predictions for end of 2018:
#
# $BTC = $25,000
# $ETH = $2,000
# $LTC = $350
# $XRP = $1.50
# $DASH = $1500
# $BCH = $200… https://t.co/dN6jbWNFRN
#
# RT @KRMA_0: There is no coming back from kamehameha part 2 @TheCryptoDog $BTC #bitcoin https://t.co/fIjK56TJWX
#
# RT @SubstratumNet: @SubstratumNet CEO @overridepro quoted in @FastCompany article on #Bitcoin $btc https://t.co/hv8lbWIWqt #sub $sub #subst…
#
# RT @ky_sachi: 12/8は+190万円ほどで終了。初のミリオン達成です。
# 惜しくも日次損益200万に届かず。一時期日次ダブルミリオンいってたんですけどね。
# それなりにいいトレードができたんじゃないかなぁと思ってます。
# 明日はダブルミリオン狙います。
# https://…
#
# Wow I don't like much of what @SantelliRants believes in politically, but I LOVED his take on $BTC futures just now… https://t.co/8iSbluvhNq
#
# RT @_mr_BTC: $BTC at the end of this week:
#
# RT @CryptosQueen: Don't ignore this. If you missed $BTC at 100s buy $LTC 100's you need to really go ALL IN. Litecoin is seriously the litt…
#
# RT @inov8interiors1: One year ago 💰 $btc $eth $xrp $ltc $xmr $etc $dash https://t.co/Q7rgimrARS
#
# RT @Rachelle_Token: @DoctorBitcoin @Seccour_FR Anyone with &gt; 1 $BTC = the new 1%
#
# Register with Binance and you can trade for as low as 0.05% fee. 3-5x cheaper than Bithumb / Bitfinex / HitBTC / Po… https://t.co/4owaS709NP
#
# Al menos tres congestiones, $BTC por fiebre de precios, red de $ETH por los gatos y $LMC por los airdrops anunciado… https://t.co/WjigOYhajI
#
# RT @FoxTradingGod: Current $DASH price: $744.11
#
# Buy on Binance with 50% discount trading fee
#
# https://t.co/xdBdYz6LZU
#
# $SNT $GNT $BTG $…
#
# Current $DASH price: $744.11
#
# Buy on Binance with 50% discount trading fee
#
# https://t.co/xdBdYz6LZU
#
# $SNT $GNT… https://t.co/eZl3jCryyu
#
# RT @YpsiNine: Calling all #Bitcoin $BTC holders! Claim your #Bitcore $BTX for free and participate in the weekly airdrops. More info here:…
#
# RT @YpsiNine: Calling all #Bitcoin $BTC holders! Claim your #Bitcore $BTX for free and participate in the weekly airdrops. More info here:…
#
# $Crypto hello guys here we go again after with some charts. I was an amazing weer for mee during this #Bitcoin $BTC… https://t.co/jSYc82CzEC
# Swedish Bitcoin Exchange-Traded Fund Bigger Than 80% of US ETFs https://t.co/ZjCFkcjFUX $BTC $ETH #Bitcoin https://t.co/ZabateVpy1
#
# 5 min #RSI Signals:
#
# $BTC - $EMC2: 23.69
# $BTC - $SBD: 28.17
# $BTC - $XZC: 31.58
# $BTC - $SALT: 32.09
# $BTC - $EDG: 34.01
#
# $SNGLS $DOPE $NMR
#
# $BQX is still at a steal of a price! Don't have #FOMO and miss this one! #Binance #Bitcoin $Btc $ltc $wtc $neo $gvt… https://t.co/Hv4G2R57yz
#
# I just earned a $10 bonus on Coinbase - follow my link so you can, too! https://t.co/UmP7bLh6fn $btc
#
# 15 min #RSI Signals:
#
# $BTC - $EMC2: 38.02
# $BTC - $SBD: 38.1
# $BTC - $DGB: 38.14
# $BTC - $SALT: 39.83
#
# $SLS $MONA $XMR $SAFEX $SPR $PTOY $TX
#
# RT @actualIizing: Bought 1,500 bitcoin in 2011 for $2.81 each. I will pick 20 random people who retweet this and give one to each of you. M…
#
# RT @CryptoGecko4: ALRIGHT GUYS ITS MY CHRISTMAS GIVEAWAY TIME
#
# RT FOLLOW TAG YOUR FRIENDS DO WHATEVER U GOTTA DO TO WIN
#
# .5 $BTC and..... t…
#
# RT @Formulix: Which crypto has the best use cases? ( #crypto $IOTA $BTC $BCH $ETH #iotatoken #Bitcoin #Ethereum #BitcoinCash )
#
# RT @BitcoinMagazine: Op-ed: #Bitcoin Is Not a Bubble; It's in an S-Curve and It's Just Getting Started https://t.co/3icGsITkT0 #blockchain…
#
# ...
#
# Starting with:
# $ZEC / BCH
# $ETH / BCH…
#
# The 5 benefits of #cryptocurrency
#
# #Blockchain #Fintech #IoT #AI #digital #disruption #CyberSecurity #technology… https://t.co/bfXal1lcGW
#
# RT @LoMoStarLMC: Right now you can find the first red envelopes with $Cfun tokens in the world view of our application! Do not miss the cha…
#
# RT @BulwarkCoin: The first #Bulwark masternodes have appeared on the network! Would you like one too? Like, Follow, Retweet and we will cho…
#
# RT @CryptosBatman: $150 dollar #giveaway worth of #Swissborg tokens to a lucky winner! 💰
#
# To participate:
# 1. Follow me
# 2. Retweet this post…
#
# RT @LatiumCoin: The Next Buyer #bonus at https://t.co/3Q9NESwW9V is a great way to participate! Go check it out now! $ETH $BTC https://t.co…
#
# RT @BulwarkCoin: The first #Bulwark masternodes have appeared on the network! Would you like one too? Like, Follow, Retweet and we will cho…
#
# RT @mBTCPizpie: This .gif is .fantastic.
# What is your profession?
#
# #bitcoin $btc https://t.co/xE5n7vzIrH
#
# RT @mango6710: I bought some bitcoin in 2011 for $2.90 each. I will pick 15 random people who retweet this and give 0.2 BTC to each of you.…
#
# RT @anxietymobile: I am fucking killing #life atm in #cryptos @bitcoin $btc Who else is with me!?
# Giving 0.1BTC away to a follower of mine…
#
# RT @TBISINC: Titanium Blockchain Infrastrucutre Services Inc. successfully listed on https://t.co/9jfoeBKEJz !
# #TBIS $BAR $XVG $BTC $ETH #E…
#
# RT @Crypto_goat_: Everyone is excited about Sunday and the futures with #Bitcoin 95% chance they short the shit out of it. Be very careful!…
#
# $BTC has formed an ascending channel inside its descending channel and is heading up with the stoch crossed or abou… https://t.co/QGwAJlwj1T
#
# RT @SubstratumNet: Getting ready for the #Developer #AMA #3 in the @SubstratumNet offices! #substratum #sub $sub #cryptocurrency #blockchai…
#
# RT @sentimentrader: Bitcoin has triggered 100% of the blow-off signals we look for. The next 1-3 months will be...interesting. $BTC $btcusd…
#
# RT @missnatoshi: To the people mostly in quality alts:
#
# A little pain now will be profits and gains later. Be patient HODL.
#
# To the people…
#
# RT @SubstratumNet: @SubstratumNet CEO @overridepro quoted in @FastCompany article on #Bitcoin $btc https://t.co/hv8lbWIWqt #sub $sub #subst…
#
# #bitcoin $BTC #ビットコイン #仮想通貨 #暗号通貨 #crypto
#
# I pulled the trigger on $BTC. $100 investment to start.
#
# RT @MasterChangz: I brought 27million $BTC in 2008 for 1doge each, retweet and follow to receive 1 whole BTC to your designated BTC address…
#
# RT @Bitcoin_Bullet: Which #country do u think is more aware about #Bitcoin : #US, #Japan or #South_Korea?
# Recent #surveys about this issue…
#
# RT @BulwarkCoin: The first #Bulwark masternodes have appeared on the network! Would you like one too? Like, Follow, Retweet and we will cho…
#
# RT @mBTCPizpie: This .gif is .fantastic.
# What is your profession?
#
# #bitcoin $btc https://t.co/xE5n7vzIrH
#
# Hi $crypto &amp; $BTC noobs or skeptics. Welcome. It may surprise you to learn that, in addition to my bags, I also own… https://t.co/vIAm2US9kF
#
# RT @Cryptodumpster: Don't get caught up in the fake news!  This is NOT an official #OKcash account. 🚨🚨🚨Scam Alert! 🚨🚨🚨 DYOR $OK $BTC #bitco…
#
# RT @CryptoBully: You really want to stick it to the banking sector?  Hit ‘em where it hurts?
#
# Then don’t use your $BTC profits to buy that…
#
# $MGTI 3Y/W Cup &amp; Handle #Bullish #Bitcoin $BTC https://t.co/6FXuEOM8F9
#
# RT @OGBTC: I bought $BTC at $0.05.
# RT and I'll give some away to 100 ppl.
#
# RT @brianleroux: $BTC hodl explains 🧐 https://t.co/g3Eh5WKEjf
#
# RT @GregaHorvatFX: Cryptocurrencies UPDATED! $BTC flying towards 15k, $ETH minor pause in uptrend,#Ripple remains in a triangle, $DASH in a…
#
# RT @JacBurns_Comext: The 5 benefits of #cryptocurrency
#
# #Blockchain #Fintech #IoT #AI #digital #disruption #CyberSecurity #technology #info…
#
# RT @Bitcoin_Bullet: Which #country do u think is more aware about #Bitcoin : #US, #Japan or #South_Korea?
# Recent #surveys about this issue…
#
# RT @mBTCPizpie: This .gif is .fantastic.
# What is your profession?
#
# #bitcoin $btc https://t.co/xE5n7vzIrH
#
# Watch @EdgeSecure CEO @paullinator  speaking about #crypto #BTC $BTC https://t.co/Tml3PCDeOm
#
# RT @sentimentrader: Bitcoin has triggered 100% of the blow-off signals we look for. The next 1-3 months will be...interesting. $BTC $btcusd…
#
# Us Senate Bill S.1241 to criminalize concealed ownership of #Bitcoin. $BTC #cryptocurrency #fintech #blockchain https://t.co/oY0ULII0re
#
# RT @CMF517: Quite the traffic jam on the $BTC blockchain! @DigiByteCoin would clear those transactions in a matter of minutes, not hours! #…
#
# RT @BulwarkCoin: The first #Bulwark masternodes have appeared on the network! Would you like one too? Like, Follow, Retweet and we will cho…
#
# $BTCUSD Is Anyone Having Issues Selling Their #Bitcoin? https://t.co/qo8gturHFQ $BTC #CryptoCurrencies… https://t.co/nlUAoo6ibM
#
# RT @Alt_crypto_life: $IOTA ascending wedge looking tight, if this concludes and $BTC futures makes Bitcoin turn bearish, we could see new A…
#
# RT @Khil0ne: Exciting times ahead for @stratisplatform ! Hope you guys will be there to witness them. Have a good weekend! #stratis #bitcoi…
#
# RT @SubstratumNet: Getting ready for the #Developer #AMA #3 in the @SubstratumNet offices! #substratum #sub $sub #cryptocurrency #blockchai…
#
# Want to accumulate some extra $BTC ?? Simply COPY the worlds best #Forex traders AUTOMATICALLY on:… https://t.co/2b8vcZKLte
#
# RT @BitcoinCashFans: CoinEx is a new exchange launching this month, trading only $BCH currency pairs!
#
# Starting with:
# $ZEC / BCH
# $ETH / BCH…
#
# RT @BulwarkCoin: The first #Bulwark masternodes have appeared on the network! Would you like one too? Like, Follow, Retweet and we will cho…
#
# RT @XVGWhale: $0.01 will break through a huge psychological barrier, we will be on the road to $1, there is 0 doubt $XVG is superior to #bi…
#
# I believe there is a low-risk long entry opportunity into #Bitcoin $BTC $XBT
#
# @jesselund @exarpee @michaeldowling @IBM @Ripple @JoelKatz @StellarOrg @TBCrypto Happy to take any conversation off… https://t.co/R0xjsxezrq
#
# Exodus wallet: what I used to claim gains in $btc &amp; buy more $ltc.
# And today ltc is up. What nice timing. #gloat
#
# RT @mango6710: I bought some bitcoin in 2011 for $2.90 each. I will pick 15 random people who retweet this and give 0.2 BTC to each of you.…
#
# RT @ryepez3: One reflexion @maxkeiser @_Kevin_Pham @BitcoinErrorLog @baijorge @BitcoinDood @cryptodemedici @BTCmemes $btc #bitcoin https://…
#
# RT @RonnieMoas: #bitcoin on sale / 15% off its high / this is normal / two steps forward ... one step back / Nothing goes up in a straight…
#
# RT @OGBTC: I bought $BTC at $0.05.
# RT and I'll give some away to 100 ppl.
#
# RT @SquawkCNBC: .@jimcramer: Bets against bitcoin $BTC will 'annihilate' the digital currency once futures begin trading https://t.co/Hu1aO…
#
# RT @OGBTC: I bought $BTC at $0.05.
# RT and I'll give some away to 100 ppl.
#
# RT @futureearn: Bought 2,530 bitcoin in 2011 for $2.7 each. I will pick 3 random people who retweet this and follow me and give one to each…
#
# RT @BulwarkCoin: The first #Bulwark masternodes have appeared on the network! Would you like one too? Like, Follow, Retweet and we will cho…
#
# Biraz $btc konusalim... https://t.co/GcBLCgUZiw
#
# RT @BulwarkCoin: The first #Bulwark masternodes have appeared on the network! Would you like one too? Like, Follow, Retweet and we will cho…
#
# RT @Khil0ne: Exciting times ahead for @stratisplatform ! Hope you guys will be there to witness them. Have a good weekend! #stratis #bitcoi…
#
# BTC、このまま勢いなくなると先物上場でショート浴びせられて一気に下げるかもしれないね。レバロングでボーナス突っ込んだ人…素人時間は終わりかも…わらう。いくで。やるで。ステラ買い増しや。 $BTC $XLM
#
# CME ( @CMEGroup ) will apply price limits, also known as circuit breakers, to its bitcoin futures of 7 percent, 13… https://t.co/Ap839s3dZE
#
# $iop is going to have some big announcement tonight !!!
#
# Current price - 36,000 sats
#
# $BTC $BCC $BCH $ETH $NEO $OMG… https://t.co/TFNO8iDbx7
#
# RT @SubstratumNet: Getting ready for the #Developer #AMA #3 in the @SubstratumNet offices! #substratum #sub $sub #cryptocurrency #blockchai…
#
# RT @CryptoStwit: $btc correction on its way, $sub moon on its way.
#
# RT @MEMESG0D: *buys 0.000001 bitcoin*
#
# *changes bio*
#
# Investor 💰 $BTC 💵 Living life in the sky ✈️ ☁️ Eat, Sleep, Bitcoin
#
# RT @chaozempire: 📛📛📛XMAS GIVEAWAY📛📛📛
# The Last Time I Gave Away 1 $BTC to @TheCryptoShriMp.
#
# 🚀🚀🚀This Time 3 winners of 50 $LUX🚀🚀🚀
#
# Rules:
# -…
# #crypto mkt cap last hour
#
# 🚀
# $ADA +148.407m
# $XLM +41.649m
# $NEO +41.067m
#
# 🌧️
# $BTC -4.054b
# $ETH -300.917m
# $XEM -127.557m
#
# #altcoins
#
# RT @BulwarkCoin: The first #Bulwark masternodes have appeared on the network! Would you like one too? Like, Follow, Retweet and we will cho…
#
# About 1000 players own 40% of Bitcoin $BTC https://t.co/4O2Wp4TM0E
#
# Looking at the big cap alts today's bounce I say that the next altcoins run is going to be the most epic ever, ther… https://t.co/v6S9FnCvGF
#
# RT @RogersFund: Anyone that bought $LTC over the past week can now trade for more $BTC than they could have afforded at the time of purchas…
#
# CoinEx is a new exchange launching this month, trading only $BCH currency pairs!
#
# Starting with:
# $ZEC / BCH
# $ETH /… https://t.co/OgbYpTq7Ig
#
# RT @BulwarkCoin: The first #Bulwark masternodes have appeared on the network! Would you like one too? Like, Follow, Retweet and we will cho…
#
# So if my $BTC trans from yesterday keeps pending till it's multiple lambo's... I'm kewl. #hodl
#
# RT @SubstratumNet: @SubstratumNet CEO @overridepro quoted in @FastCompany article on #Bitcoin $btc https://t.co/hv8lbWIWqt #sub $sub #subst…
#
# RT @anxietymobile: I am fucking killing #life atm in #cryptos @bitcoin $btc Who else is with me!?
# Giving 0.1BTC away to a follower of mine…
#
# RT @cryptoniac90: Did you sell your #alts for $btc or $?
#
# RT @EtherHood: $crypto people:
#
# the $ETH #faucet is OPEN today for the next 4 hours; here are the rules:
#
# 1. follow me and retweet this
# 2.…
#
# 5 min #RSI Signals:
#
# $BTC - $IOP: 38.79
#
# $TIX $FLO $TIME $EMC2 $SBD $ION $BAY $SALT $EDG $RLC $AGRS $DGD $MEME $SPHR $PINK $SPR $DASH $SC
#
# OMG! Just opened two new $BTC trades and they're negative. Takes some getting used to. #bitcoin #Crypto
#
# ⬇ -2 Russian Regulators Draft Law to Restrict Crypto Mining, Payments, and Token Sales https://t.co/xvwnW0VkoS $BTC #bitcoin #ethereum
#
# No one helped so far. Disheartening but not lost hope. Have trust in my Lord. He'll send someone to help. He, The G… https://t.co/h4cR6faXim
#
# RT @SubstratumNet: Getting ready for the #Developer #AMA #3 in the @SubstratumNet offices! #substratum #sub $sub #cryptocurrency #blockchai…
#
# RT @BulwarkCoin: The first #Bulwark masternodes have appeared on the network! Would you like one too? Like, Follow, Retweet and we will cho…
#
# Anyone that bought $LTC over the past week can now trade for more $BTC than they could have afforded at the time of… https://t.co/jRRi9KwTYT
#
# 2/2 Once trading resumes, if the best bid in the $XBT futures contract closest to expiration is 20 percent or more… https://t.co/oe3PR5vFHv
#
# RT @BulwarkCoin: The first #Bulwark masternodes have appeared on the network! Would you like one too? Like, Follow, Retweet and we will cho…
#
# RT @decredproject: You can now compare #Decred to other $crypto projects on specifications, features, and governance.
#
# This iteration inclu…
#
# @MadMoneyOnCNBC @jebus911 @jimcramer Lol, you shill crap stocks that return 25% on a good year. No one really needs… https://t.co/32ehBvlsGR
#
# RT @LunyrInc: $LUN are now usable on the Lunyr platform! Another milestone achieved! https://t.co/fxhrUMvF0l #ETHEREUM #Bitcoin #Blockchain…
#
# RT @TraceMayer: #Bitcoin now a solid top-20 world currency surpassing Sweden. $16k $BTC &amp; $275B market cap only tip of 1st root of 1st netw…
#
# RT @TaIhaYilmaz: 1 $LTC #giveaway to one randomly chosen follower.
# Rules are
# 1. Follow
# 2. Retweet
# 3. Comment your wallet address
#
# Winne…
#
# RT @BulwarkCoin: The first #Bulwark masternodes have appeared on the network! Would you like one too? Like, Follow, Retweet and we will cho…
#
# RT @btc: Bitcoin Giveaway #2: As promised, we will be giving away 1 BTC when we hit 100k followers! Please RT and Follow for a chance to wi…
#
# RT @BulwarkCoin: The first #Bulwark masternodes have appeared on the network! Would you like one too? Like, Follow, Retweet and we will cho…
#
# RT @iiblockchain: GIVEAWAY ALERT!
#
# $100 of #STRATIS
#
# We are sending $100 worth of $STRAT to a lucky follower who RT's this message and giv…
#
# RT @XVGWhale: $XVG has just hit a new all time high today, $0.0091! We are getting very close to breaking the $0.01 threshold for the first…
#
# RT @BulwarkCoin: The first #Bulwark masternodes have appeared on the network! Would you like one too? Like, Follow, Retweet and we will cho…
#
# RT @parabolictrav: I'm starting to take the controversial position that I'm less looking at a financial market chart and more looking at a…
#
# RT @CryptoWolfPack: FOLLOW US, LIKE AND RETWEET THE BELOW TWEET TO ENTER OUR FREE $BTC #GIVEAWAY NOW!!!
#
# 🚀🚀🤑🤑🐺🐺
#
# $SYS $QTUM $WINGS $BTS $MC…
#
# RT @BulwarkCoin: The first #Bulwark masternodes have appeared on the network! Would you like one too? Like, Follow, Retweet and we will cho…
#
# RT @CryptoBully: You really want to stick it to the banking sector?  Hit ‘em where it hurts?
#
# Then don’t use your $BTC profits to buy that…
#
# RT @BulwarkCoin: The first #Bulwark masternodes have appeared on the network! Would you like one too? Like, Follow, Retweet and we will cho…
#
# RT @BulwarkCoin: The first #Bulwark masternodes have appeared on the network! Would you like one too? Like, Follow, Retweet and we will cho…
#
# If I was to write an e book (free) on cryptocurrencies what would you like to see in it? #btc #bitcoin $btc
#
# RT @Aminder17: 1btc giveaway on first 1000 followers
#
# $btc $eth $xrp $bch $neo $ven $omg $dash $xmr $etc $lsk $wtc $etp $iota $powr $qsp $…
#
# 1/2 Cboe ( @CBOE ) will halt trading in its contract for 2 minutes if the best bid in the $XBT futures contract clo… https://t.co/ecKNT81zIp
#
# the way $bco is holding its price through this madness $btc run is more than impressive, the daily signups show a d… https://t.co/lErJA1w1G4
#
# RT @dynasty1347: Zoom out to begin. $strat weekly on BTC looks good. 3 consecutive weeks of growth and increased volume combined with the F…
# ---------------------------------------------------------------------------
# TweepError                                Traceback (most recent call last)
# <ipython-input-10-2fb25b7b340b> in <module>()
# ----> 1 for tweet in tweepy.Cursor(extractor.search, q = search_text, rpp=100).items(100000):
#       2     print(tweet.text)
#       3     print()
#
# /anaconda/lib/python3.6/site-packages/tweepy/cursor.py in __next__(self)
#      47
#      48     def __next__(self):
# ---> 49         return self.next()
#      50
#      51     def next(self):
#
# /anaconda/lib/python3.6/site-packages/tweepy/cursor.py in next(self)
#     195         if self.current_page is None or self.page_index == len(self.current_page) - 1:
#     196             # Reached end of current page, get the next page...
# --> 197             self.current_page = self.page_iterator.next()
#     198             self.page_index = -1
#     199         self.page_index += 1
#
# /anaconda/lib/python3.6/site-packages/tweepy/cursor.py in next(self)
#     106
#     107         if self.index >= len(self.results) - 1:
# --> 108             data = self.method(max_id=self.max_id, parser=RawParser(), *self.args, **self.kargs)
#     109
#     110             if hasattr(self.method, '__self__'):
#
# /anaconda/lib/python3.6/site-packages/tweepy/binder.py in _call(*args, **kwargs)
#     243             return method
#     244         else:
# --> 245             return method.execute()
#     246
#     247     # Set pagination mode
#
# /anaconda/lib/python3.6/site-packages/tweepy/binder.py in execute(self)
#     227                     raise RateLimitError(error_msg, resp)
#     228                 else:
# --> 229                     raise TweepError(error_msg, resp, api_code=api_error_code)
#     230
#     231             # Parse the response payload
#
# TweepError: Twitter error response: status code = 429
